# %% [markdown]
# ## Import libraries and API Keys

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import display, Markdown
from pprint import pprint

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise ValueError("OPENAI_API_KEY environment variable not set")

# %%
client = OpenAI()

completion = client.chat.completions.create(
    model= "gpt-4o-mini-search-preview",
    messages = [
        {"role": "system", "content":"you are a helpful assistant"},
        {"role": "user", "content": "what is today's date? tell me the top 3 stories in AI in this week, according to relliable sources."}
    ],
    max_tokens=500
)

# %%
search_results = completion.choices[0].message.content
display(Markdown(search_results))
# Out:
# As of today, Monday, June 22, 2026, here are the top three AI stories from the week of June 15–21, 2026, based on reliable sources:
#
# 1. **OpenAI's IPO Plans and Market Impact**: OpenAI has taken significant steps toward becoming a publicly traded company, with reports indicating that the company is preparing for an initial public offering (IPO). This move is expected to have a substantial impact on the AI industry, potentially setting a precedent for other AI companies considering similar paths. ([hubevery.com](https://hubevery.com/weekly-roundup-top-ai-news-this-week-june-2026/?utm_source=openai))
#
# ...

# %% [markdown]
# ## Step 3: Summarize and write social media post

# %%
system_message = """ You are a helpful assistant that provides information about the latest news in AI based on text from reliable sources. 
Make the post engaging and interesting. 
Also make concise and add a thought provoking question at the end to encourage readers to comment."""

prompt = f"""
The following is a list of the top 3 stories in AI this week, according to reliable sources.
now please write a LinkedIn post based on the following information.

{search_results}
"""


completion = client.chat.completions.create(
    model= "gpt-4o-mini",
    messages = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": prompt}
    ],
    max_tokens=500,
    temperature=0.7
)   

chat_response = completion.choices[0].message.content
display(Markdown(chat_response))
# Out:
# 🚀 **Weekly AI Roundup: Key Developments Shaping the Future** 🚀
#
# As of today, June 22, 2026, the AI landscape is buzzing with significant news that could reshape the industry:
#
# 1. **OpenAI's IPO Plans**: OpenAI is gearing up for an initial public offering, a move that could revolutionize the AI market and inspire other companies to follow suit. The implications of this IPO could set new benchmarks for investment and innovation in artificial intelligence. ([Read more here](https://hubevery.com/weekly-roundup-top-ai-news-this-week-june-2026/?utm_source=openai))
#
# ...
