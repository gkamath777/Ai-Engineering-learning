# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables.

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("OPENAI_API_KEY environment variable not set")
else:
    print("OPENAI_API_KEY environment variable is set")
    print("OPENAI_API_KEY:", OPENAI_API_KEY[:8])
# Out:
# OPENAI_API_KEY environment variable is set
# OPENAI_API_KEY: sk-proj-

# %% [markdown]
# Step 2: Call the API

# %%
client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "user", "content": "do you know Gaurav Kamath who worked in deloitte during 2017-2019?"}
    ]
)

print(response.choices[0].message.content)
# Out:
# I don’t have access to personal data about individuals unless it has been shared publicly. Therefore, I don’t have information about Gaurav Kamath or his employment at Deloitte between 2017-2019. If you’re looking to connect with him professionally, I recommend checking platforms like LinkedIn or contacting Deloitte directly. Is there something else I can assist you with?
