# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables.

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display

load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("OPENAI_API_KEY environment variable not set")
else:
    print("OPENAI_API_KEY environment variable is set")
    print("OPENAI_API_KEY:", OPENAI_API_KEY[:8])

client = OpenAI()
# Out:
# OPENAI_API_KEY environment variable is set
# OPENAI_API_KEY: sk-proj-

# %% [markdown]
# ### Call the API

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": "you are a helpful assistant."},
        {"role": "user", "content": "I am going to travel to India next week"}]
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# That sounds exciting! India is a beautiful and diverse country with so much to explore. Do you need any tips or information for your trip, such as visa requirements, packing suggestions, places to visit, or cultural customs? Let me know how I can help!

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[
        {"role": "system", "content": "you are a helpful assistant."},
        {"role": "user", "content": "where am I going next week"}]
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# I don’t have access to your personal schedule or location information. If you share more details about your plans, I’d be happy to help you organize or prepare for your trip!

# %% [markdown]
# ### In Theory

# %%
messages = [
    {"role": "system", "content": "you are a helpful assistant."},
    {"role": "user", "content": "I am going to travel to India next week"},
    {"role": "assistant", "content": "That's great! India is a beautiful country with a rich cultural heritage. Do you have any specific places in mind that you plan to visit?"},
    {"role": "user", "content": "where am I going next week"}
]

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# You mentioned that you are going to India next week. If you need help planning your trip or tips for your visit, feel free to ask!

# %% [markdown]
# ### Now Not manually!!

# %%
messages=[
        {"role": "system", "content": "you are a helpful assistant."},
        {"role": "user", "content": "I am going to travel to India next week"}]

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role": "assistant", "content": reply})
#display(Markdown(reply))

print(messages)
# Out:
# [{'role': 'system', 'content': 'you are a helpful assistant.'}, {'role': 'user', 'content': 'I am going to travel to India next week'}, {'role': 'assistant', 'content': 'That sounds exciting! India is a diverse and vibrant country with a rich cultural heritage. Do you need any specific information or tips for your trip? For example, recommendations on places to visit, travel tips, local customs, or packing advice?'}]

# %%
from pprint import pprint
pprint(messages)
# Out:
# [{'content': 'you are a helpful assistant.', 'role': 'system'},
#  {'content': 'I am going to travel to India next week', 'role': 'user'},
#  {'content': 'That sounds exciting! India is a diverse and vibrant country '
#              'with a rich cultural heritage. Do you need any specific '
#              'information or tips for your trip? For example, recommendations '
#              'on places to visit, travel tips, local customs, or packing '
#              'advice?',
#   'role': 'assistant'}]

# %%
messages.append({"role": "user", "content": "where am I going next week"})
pprint(messages)
# Out:
# [{'content': 'you are a helpful assistant.', 'role': 'system'},
#  {'content': 'I am going to travel to India next week', 'role': 'user'},
#  {'content': 'That sounds exciting! India is a diverse and vibrant country '
#              'with a rich cultural heritage. Do you need any specific '
#              'information or tips for your trip? For example, recommendations '
#              'on places to visit, travel tips, local customs, or packing '
#              'advice?',
#   'role': 'assistant'},
#  {'content': 'where am I going next week', 'role': 'user'}]

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role": "assistant", "content": reply})
#display(Markdown(reply))
pprint(messages)
# Out:
# [{'content': 'you are a helpful assistant.', 'role': 'system'},
#  {'content': 'I am going to travel to India next week', 'role': 'user'},
#  {'content': 'That sounds exciting! India is a diverse and vibrant country '
#              'with a rich cultural heritage. Do you need any specific '
#              'information or tips for your trip? For example, recommendations '
#              'on places to visit, travel tips, local customs, or packing '
#              'advice?',
#   'role': 'assistant'},
#  {'content': 'where am I going next week', 'role': 'user'},
#  {'content': 'You mentioned that you are going to India next week. Is there '
#              "anything specific you'd like to know or plan for your trip?",
#   'role': 'assistant'},
#  {'content': 'You mentioned that you are traveling to India next week. If you '
#              'need any help with travel tips, places to visit, or anything '
#              'else, feel free to ask!',
#   'role': 'assistant'}]

# %%
messages.append({"role": "user", "content": "What is the capital of India?"})
pprint(messages)
# Out:
# [{'content': 'you are a helpful assistant.', 'role': 'system'},
#  {'content': 'I am going to travel to India next week', 'role': 'user'},
#  {'content': 'That sounds exciting! India is a diverse and vibrant country '
#              'with a rich cultural heritage. Do you need any specific '
#              'information or tips for your trip? For example, recommendations '
#              'on places to visit, travel tips, local customs, or packing '
#              'advice?',
#   'role': 'assistant'},
#  {'content': 'where am I going next week', 'role': 'user'},
#  {'content': 'You mentioned that you are going to India next week. Is there '
#              "anything specific you'd like to know or plan for your trip?",
#   'role': 'assistant'},
#  {'content': 'You mentioned that you are traveling to India next week. If you '
#              'need any help with travel tips, places to visit, or anything '
#              'else, feel free to ask!',
#   'role': 'assistant'},
# ...

# %%
response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role": "assistant", "content": reply})
#display(Markdown(reply))
pprint(messages)
# Out:
# [{'content': 'you are a helpful assistant.', 'role': 'system'},
#  {'content': 'I am going to travel to India next week', 'role': 'user'},
#  {'content': 'That sounds exciting! India is a diverse and vibrant country '
#              'with a rich cultural heritage. Do you need any specific '
#              'information or tips for your trip? For example, recommendations '
#              'on places to visit, travel tips, local customs, or packing '
#              'advice?',
#   'role': 'assistant'},
#  {'content': 'where am I going next week', 'role': 'user'},
#  {'content': 'You mentioned that you are going to India next week. Is there '
#              "anything specific you'd like to know or plan for your trip?",
#   'role': 'assistant'},
#  {'content': 'You mentioned that you are traveling to India next week. If you '
#              'need any help with travel tips, places to visit, or anything '
#              'else, feel free to ask!',
#   'role': 'assistant'},
# ...
