# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}
"""

    messages = []
    add_user_message(messages, prompt)
    output = chat(messages)
    return output

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 6

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "# Parse AWS S3 Bucket Name\n\nHere are several ways to extract the bucket name from an S3 URI:\n\n## Method 1: Using String Split (Simple)\n```python\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name from S3 URI\"\"\"\n    # Remove 's3://' prefix and split by '/'\n    return s3_uri.replace('s3://', '').split('/')[0]\n\n# Example usage\ns3_uri = 's3://my-bucket/path/to/key'\nbucket_name = get_bucket_name(s3_uri)\nprint(bucket_name)  # Output: my-bucket\n```\n\n## Method 2: Using Regular Expression (Robust)\n```python\nimport re\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name using regex\"\"\"\n    match = re.match(r's3://([a-zA-Z0-9._-]+)', s3_uri)\n    return match.group(1) if match else None\n\n# Example usage\ns3_uri = 's3://my-bucket/path/to/key'\nbucket_name = get_bucket_name(s3_uri)\nprint(bucket_name)  # Output: my-bucket\n```\n\n## Method 3: Using urllib (URL Parsing)\n```python\nfrom urllib.parse import urlparse\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name using urllib\"\"\"\n    parsed = urlparse(s3_uri)\n    return parsed.netloc\n\n# Example usage\ns3_uri = 's3://my-bucket/path/to/key'\nbucket_name = get_bucket_name(s3_uri)\nprint(bucket_name)  # Output: my-bucket\n```\n\n## Method 4: Using boto3 (AWS SDK)\n```python\nfrom botocore.compat import urlparse\n\ndef get_bucket_name(s3_uri):\n    \"\"\"Extract bucket name using boto3 utilities\"\"\"\n    parts = urlparse(s3_uri)\n    return parts.netloc\n\n# Example usage\ns3_uri = 's3://my-bucket/path/to/key'\nbucket_name = get_bucket_name(s3_uri)\nprint(bucket_name)  # Output: my-bucket\n```\n\n## Test Cases\n```python\ntest_cases = [\n    's3://my-bucket/key',\n    's3://my-bucket/path/to/key',\n    's3://my-bucket-123/file.txt',\n    's3://bucket.with.dots/path',\n]\n\nfor uri in test_cases:\n    print(f\"{uri} \u2192 {get_bucket_name(uri)}\")\n```\n\n**Recommendation:** Use **Method 1** for simplicity or **Method 3** for robustness and proper URL parsing.",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name from an S3 URI in the format 's3://bucket-name/key/path' and extract just the bucket name",
#       "format": "regex"
#     },
#     "score": 6,
#     "reasoning": "The solution demonstrates good awareness of multiple approaches, but has technical issues. Method 3 is correctly recommended and is the best choice for AWS use cases. However, the other methods have significant flaws: Method 1 is too simplistic without error handling, Method 2's regex is incomplete against AWS bucket naming rules, and Method 4 unnecessarily uses private boto3 dependencies. The solution would benefit from input validation, error handling, and removing the problematic Method 4 recommendation."
#   },
#   {
#     "output": "# CloudFormation Template for S3 Bucket with Versioning and Public Access Blocked\n\n```json\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Description\": \"CloudFormation template to create an S3 bucket with versioning enabled and public access blocked\",\n  \"Resources\": {\n    \"S3Bucket\": {\n      \"Type\": \"AWS::S3::Bucket\",\n      \"Properties\": {\n        \"BucketName\": {\n          \"Fn::Sub\": \"my-bucket-${AWS::AccountId}-${AWS::Region}\"\n        },\n        \"VersioningConfiguration\": {\n          \"Status\": \"Enabled\"\n        }\n      }\n    },\n    \"S3BucketPublicAccessBlock\": {\n      \"Type\": \"AWS::S3::AccountPublicAccessBlock\",\n      \"Properties\": {\n        \"AccountId\": {\n          \"Ref\": \"AWS::AccountId\"\n        },\n        \"BlockPublicAcls\": true,\n        \"BlockPublicPolicy\": true,\n        \"IgnorePublicAcls\": true,\n        \"RestrictPublicBuckets\": true\n      }\n    }\n  },\n  \"Outputs\": {\n    \"BucketName\": {\n      \"Description\": \"Name of the S3 bucket\",\n      \"Value\": {\n        \"Ref\": \"S3Bucket\"\n      }\n    },\n    \"BucketArn\": {\n      \"Description\": \"ARN of the S3 bucket\",\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"S3Bucket\",\n          \"Arn\"\n        ]\n      }\n    }\n  }\n}\n```\n\n## Key Features:\n\n1. **Versioning Enabled**: The `VersioningConfiguration` property with `Status: \"Enabled\"` enables version control for all objects in the bucket\n\n2. **Public Access Blocked**: The `AWS::S3::AccountPublicAccessBlock` resource blocks:\n   - `BlockPublicAcls`: Blocks public ACLs on buckets and objects\n   - `BlockPublicPolicy`: Blocks public bucket policies\n   - `IgnorePublicAcls`: Ignores existing public ACLs\n   - `RestrictPublicBuckets`: Restricts public bucket access\n\n3. **Unique Bucket Name**: Uses `AWS::AccountId` and `AWS::Region` to generate a unique bucket name\n\n4. **Outputs**: Provides the bucket name and ARN for reference\n\nThis template ensures a secure S3 bucket configuration following AWS best practices.",
#     "test_case": {
#       "task": "Create a CloudFormation template JSON object that defines a simple S3 bucket with versioning enabled and public access blocked",
#       "format": "json"
#     },
#     "score": 5,
#     "reasoning": "The solution demonstrates understanding of the core requirements (versioning and public access blocking) and includes good practices like unique naming and outputs. However, it contains a critical architectural error by using the account-level public access block resource instead of the bucket-level equivalent. This means the public access blocking would apply account-wide rather than to just this bucket, which is impractical for real-world scenarios where you may have multiple buckets with different access requirements. The omission of encryption is a secondary concern but represents incomplete security hardening."
#   },
#   {
#     "output": "# AWS IAM ARN Parser\n\nHere's a Python function that extracts the account ID from an AWS IAM ARN:\n\n```python\ndef extract_account_id_from_arn(arn: str) -> str:\n    \"\"\"\n    Extract the AWS account ID from an IAM ARN string.\n    \n    ARN format: arn:partition:service:region:account-id:resource-type/resource-id\n    \n    Args:\n        arn: AWS IAM ARN string\n        \n    Returns:\n        The account ID (12-digit string)\n        \n    Raises:\n        ValueError: If the ARN format is invalid or account ID is not found\n    \"\"\"\n    if not isinstance(arn, str):\n        raise ValueError(\"ARN must be a string\")\n    \n    parts = arn.split(\":\")\n    \n    if len(parts) < 5:\n        raise ValueError(f\"Invalid ARN format: {arn}\")\n    \n    account_id = parts[4]\n    \n    if not account_id:\n        raise ValueError(\"Account ID is empty in the provided ARN\")\n    \n    return account_id\n\n\n# Test cases\nif __name__ == \"__main__\":\n    # Test with various ARN formats\n    test_cases = [\n        \"arn:aws:iam::123456789012:user/Development/product_1/*\",\n        \"arn:aws:iam::123456789012:role/MyRole\",\n        \"arn:aws:s3:::my-bucket/*\",  # S3 ARN (no account ID)\n        \"arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\",\n        \"arn:aws:lambda:us-west-2:123456789012:function:my-function\",\n    ]\n    \n    for arn in test_cases:\n        try:\n            account_id = extract_account_id_from_arn(arn)\n            print(f\"ARN: {arn}\")\n            print(f\"Account ID: {account_id}\\n\")\n        except ValueError as e:\n            print(f\"ARN: {arn}\")\n            print(f\"Error: {e}\\n\")\n```\n\n**Output:**\n```\nARN: arn:aws:iam::123456789012:user/Development/product_1/*\nAccount ID: 123456789012\n\nARN: arn:aws:iam::123456789012:role/MyRole\nAccount ID: 123456789012\n\nARN: arn:aws:s3:::my-bucket/*\nError: Account ID is empty in the provided ARN\n\nARN: arn:aws:ec2:us-east-1:123456789012:instance/i-1234567890abcdef0\nAccount ID: 123456789012\n\nARN: arn:aws:lambda:us-west-2:123456789012:function:my-function\nAccount ID: 123456789012\n```\n\n## How it works:\n\n1. **Validates input**: Checks if the ARN is a string\n2. **Splits the ARN**: Uses `split(\":\")` to break the ARN into parts\n3. **Extracts account ID**: The account ID is always at index 4 (the 5th element) in AWS ARNs\n4. **Error handling**: Raises `ValueError` for invalid formats\n\n## ARN Structure:\n```\narn:partition:service:region:account-id:resource\n     0        1       2      3       4       5+\n```\n\nThe account ID is the 5th component (index 4) in the colon-separated ARN string.",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS IAM ARN string and returns the account ID from it",
#       "format": "python"
#     },
#     "score": 7,
#     "reasoning": "The solution provides a functional and well-documented approach to extracting account IDs from ARNs. The core logic is correct for well-formed ARNs, and the code structure is professional. However, it lacks sufficient validation of the extracted account ID itself. The function catches empty account IDs but would accept invalid formats like special characters or incorrect lengths. Additionally, the check for empty strings occurs after extraction, which is good, but regex validation of the account ID format (12 digits) would be more robust. For a production AWS tool, this solution works for typical cases but could fail with edge cases or malformed input."
#   }
# ]
