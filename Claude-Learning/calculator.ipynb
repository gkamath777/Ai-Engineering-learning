# %%
from dotenv import load_dotenv
from anthropic import Anthropic


load_dotenv()
client = Anthropic()
model = "claude-haiku-4-5-20251001"

SYSTEM_PROMPT = """
you are a patient math tutor. Do not directly answer a student's questions. Guide them to a solution step by step
"""

def add_user_message(messages, text): 
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages
    }

    if system:
        params["system"] = system

    message = client.messages.create (**params)
    return message.content[0].text



# Define the message object
messages = []
answer = '0'

# Use "While True" loop to run the chatbot forever
flag = True
while flag:
    #get user input
    print(f"current value {answer}\n")
    print("add the number(s) and mention the operations to perform \n")
    print("for New Chat type 'new' and to exit type 'exit'")
    user_input = input("> ")
    print(f"> {user_input}")
    
    if user_input == "exit":
        flag=False
        break

    if user_input == "new":
        messages=[]
        continue

    # Add usr input to the list of messages
    add_user_message(messages, user_input)

    # Call claude with the 'chat' function
    answer = chat(messages)

    # Add generated text to the list of messages
    add_assistant_message(messages, answer)

    # Print the generated text
    print(f"Answer: \n{answer}")
# Out:
# current value 0
#
# add the number(s) and mention the operations to perform
#
# for New Chat type 'new' and to exit type 'exit'
# > 1+2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 65
#      61     # Add usr input to the list of messages
#      62     add_user_message(messages, user_input)
#      63
#      64     # Call claude with the 'chat' function
# ---> 65     answer = chat(messages, temperature=0.0)
#      66
#      67     # Add generated text to the list of messages
#      68     add_assistant_message(messages, answer)
#
# Cell In[11], line 34, in chat(messages, system, temperature)
#      30
#      31     if system:
#      32         params["system"] = system
#      33
# ---> 34     message = client.messages.create (**params)
#      35     return message.content[0].text
#
# File ~/Documents/Code/ai-engineering/ai_env/lib/python3.14/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# TypeError: Messages.create() got an unexpected keyword argument 'temperature'
