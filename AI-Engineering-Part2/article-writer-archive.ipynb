# %% [markdown]
# ### Install new libraries

# %%
#!pip install ddgs trafilatura -q # -q without any logs
#!pip install openai-agents
#!pip install boto3

# %% [markdown]
# ### Step 0: Setup imports

# %%
import os
from dotenv import load_dotenv
from pprint import pprint
import json
from ddgs import DDGS
import trafilatura
from IPython.display import Image, display, Markdown
from openai import OpenAI
from agents import trace, Agent, Runner, function_tool, handoff
from agents.extensions.handoff_prompt import RECOMMENDED_PROMPT_PREFIX
import base64
import boto3
import uuid
import io

load_dotenv()
openai_client = OpenAI()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API Key is Missing")

MODEL="gpt-4o-mini"
#MODEL="gpt-5.6-luna"

# %% [markdown]
# ### Step 1: Function tools

# %%
@function_tool
def search_web(query: str):
    """ Search the web using DuckDuckGo browser. Return 3 results."""
    ddgs = DDGS()
    results = ddgs.text(query, max_results=10)
    print(f"\u2705 search_web: Got results {query}")
    return json.dumps(results, indent=2)

# %%
@function_tool
def fetch_url(url: str):
    """Fetch the content of a URL using trafilatura"""
    downloaded = trafilatura.fetch_url(url)
    if downloaded:
        text = trafilatura.extract(downloaded)
        if text:
            print(f"\u2705 fetch_url: Got {len(text)} chars from {url[:60]}")
            return text
    print(f"\u274c Failed to fetch or extract test fron {url}.")
    return f"Could not extract the text from {url}. try a different source"

# %%
@function_tool
def generate_image1(prompt: str):
    """Generate an image using OpenAI's gpt-image-2 API. The prompt should be a detailed visual description"""
    
    response = openai_client.images.generate(
        model="gpt-image-2",
        prompt=prompt,
        size="1024x1024",
        quality="high",
        n=1)

    # GPT Image returns Base64 image data
    image_base64 = response.data[0].b64_json

    # Decode Base64
    image_bytes = base64.b64decode(image_base64)

    # Save image locally
    image_path = "generated_image.png"

    with open(image_path, "wb") as file:
        file.write(image_bytes)

    print(f"✅ generate_image: done")
    print(f"✅ Image saved to: {image_path}")

    return image_path

# %%
GENERATED_IMAGES = []  # module-level

@function_tool
def generate_image2(prompt: str):
    """Generate an image using OpenAI's gpt-image-2 API and return its public URL. The prompt should be a detailed visual description"""
    
    response = openai_client.images.generate(
        model="gpt-image-2",
        prompt=prompt,
        size="1024x1024",
        quality="high",
        n=1)

    # GPT Image returns Base64 image data
    image_base64 = response.data[0].b64_json

    # Decode Base64
    image_bytes = base64.b64decode(image_base64)

    # Save image locally
    image_path = "generated_image.png"

    with open(image_path, "wb") as file:
        file.write(image_bytes)

    print(f"✅ generate_image: done")
    print(f"✅ Image saved to: {image_path}")

    GENERATED_IMAGES.append(image_path)
    return image_path

# %%
if not os.getenv("AWS_S3_BUCKET"):
    raise RuntimeError("AWS_S3_BUCKET is missing")

s3_client = boto3.client("s3")
s3_bucket = os.environ["AWS_S3_BUCKET"]


@function_tool
def generate_image(prompt: str) -> str:
    """"Generate an image using OpenAI's gpt-image-2 API, upload it to S3, and return its private URL. The prompt should be a detailed visual description"""

    print(f"🎨 Generating image for: {prompt}")

    response = openai_client.images.generate(
        model="gpt-image-2",
        prompt=prompt,
        size="1024x1024",
        quality="high",
        n=1,
    )

    image_base64 = response.data[0].b64_json

    if not image_base64:
        raise RuntimeError("The image API did not return image data")

    image_bytes = base64.b64decode(image_base64)
    object_key = f"generated-images/{uuid.uuid4()}.png"

    # Upload directly from memory — no local file is created.
    s3_client.upload_fileobj(
        io.BytesIO(image_bytes),
        s3_bucket,
        object_key,
        ExtraArgs={
            "ContentType": "image/png",
            "ContentDisposition": "inline",
        },
    )

    # Private URL valid for one hour.
    image_url = s3_client.generate_presigned_url(
        "get_object",
        Params={
            "Bucket": s3_bucket,
            "Key": object_key,
        },
        ExpiresIn=3600,
    )

    print(f"✅ Image uploaded: {image_url}")
    return image_url

# %% [markdown]
# ### Step 2: The Agent Prompt tells the LLM *who it is* and *how to behave*.
# #### The key things:
# - what its job is
# - What tool it has
# - what process to follow
# - what output format to produce

# %% [markdown]
# #### Research Agent

# %%
RESEARCH_AGENT_PROMPT = """You are a research specialist. Your job is to research a given topic
and produce a comprehensive research brief.

You have access to two tools:
- search_web: Search the web for information
- fetch_url: Fetch and read the full content of a web page

***IMPORTANT:
After each search with search_web, you MUST first explain your reasoning:
- Which URLs look most relevant and why
- Which ones you will fetch and why
- Which ones you are skipping and why
Only AFTER writing out your reasoning should you call fetch_url.***

Your typical process:
1. Search for the topic to find relevant sources
2. Reflect on the search results — which sources look most relevant and why?
3. Fetch the full content of the 2-3 best URLs
4. Reflect on what you have gathered. Do you have enough? Are there gaps?
5. If there are gaps, search again with a different query
6. When you have enough information from at least 3 different sources, synthesize into a research brief

You MUST gather information from at least 3 distinct sources before delivering your brief. 
If you have fewer than 3 sources, keep searching.

Your research brief MUST include:
- Key facts and statistics
- Main themes and arguments from the sources
- Notable data points
- Source URLs for attribution

Until you are ready, just keep working — search, fetch, think, reflect.
Do not rush. Take time to reflect between tool calls before deciding your next step.
Not every response needs a tool call — sometimes just thinking through what you have is the right move."""


research_agent = Agent(
    name = "Research Agent",
    instructions = RESEARCH_AGENT_PROMPT,
    model = MODEL,
    tools = [search_web, fetch_url]
)

# %% [markdown]
# ### Image Generatrion Agent

# %%
IMAGE_AGENT_PROMPT = """You are an image prompt specialist. Given a topic and content summary,
craft a detailed gpt-image-2 prompt for a hero image.

Rules for your gpt-image-2 prompt:
- Describe a natural, photographic-style image (not illustrated, not cartoon)
- No text, logos, or words in the image
- No human faces or recognizable people
- No icon dumps or collages
- Focus on a single compelling visual that captures the theme
- Be specific about lighting, composition, and mood
- Keep the prompt under 200 words

Call generate_image exactly ONCE with your prompt. One image only.
"""

image_agent = Agent(
    name = "Image Agent",
    instructions = IMAGE_AGENT_PROMPT,
    model = MODEL,
    tools = [generate_image]
)

image_agent_as_tool = image_agent.as_tool(tool_name="image_agent", tool_description="Generate a hero image for the article, pass the topic and content summary as input")

# %% [markdown]
# ### Orchestrator Agent

# %%
ORCHESTRATOR_AGENT_PROMPT = RECOMMENDED_PROMPT_PREFIX + """
You are the orchestrator of a multi-agent article writing system.
Your job is to coordinate tools and other agents to produce a high-quality article. 
Use the tools available to you and/or delegate tasks to the appropriate agents.
Never do the work yourself. Always use tools or agents. 
Your tools and agents are specialists and should be doing the work, you are the manager.

You use the research_agent tool twice (and ONLY twice) with slightly varying inputs to get 2 research briefs.
You pick the best research brief out of the two and deliver it as output. 
Do not combine the two briefs, just pick the best one.
Do not do the research yourself or add anything, you MUST use the research_agent tool to get the briefs.

Once you have selected the best brief, you MUST use the image_agent tool to generate an image.
use the research brief to supply the image agent with the topic and content summary it needs to generate the image.

Handoff the research brief to the journalist writer Agent, 
and include the image URL as part of your handoff.

IMPORTANT: When passing the image URL, copy it Exactly as returned by the image_agent tool. Do not modify it in any way.
"""

#Deliver the selected research brief as the final output, and 
#include the image at the top of your final output in Markdown format like this ![hero image](image_url)

orchestrator_agent = Agent(
    name = "orchestrator_agent",
    instructions=ORCHESTRATOR_AGENT_PROMPT,
    #model= "gpt-5-mini",
    model = MODEL,
    tools = [research_agent.as_tool(tool_name="research_agent", tool_description="Research a topic and return a brief with key fscts, statistics, themes, and source URLs, pass the topic as input"),
             image_agent_as_tool]
)

# %% [markdown]
# ### Writer Agent A: The Journalist

# %%
JOURNALIST_WRITER_PROMPT = RECOMMENDED_PROMPT_PREFIX + """You are an investigative journalist. 
You will receive a conversation history that includes research on a topic. 

Your style: 
- Lead with the most surprising or controversial finding — your opening should grab the reader 
- Challenge assumptions and ask hard questions throughout 
- Take a clear stance — you have an opinion and you're not afraid to share it 
- Quote sources and reference specific data points 
- Write in a conversational, punchy tone — short paragraphs, varied sentence length 
- Structure like a news feature: hook, context, evidence, tension, conclusion 
- Aim for 800-1200 words 

Do NOT use generic section headers like "Introduction", "Conclusion", or "Overview". Use creative, specific headers to grab the attention.
Do NOT overuse headers. Only use one title and between 2 and 3 headers in total for the entire article.
Do NOT use Bullet points or numbered lists.
Do NOT ask for feedback, offer revisions, or include any commentary after the article. 
Just deliver the finished article in markdown format. 

The conversation history contains an image_agent result.

Extract the exact Markdown image reference returned by image_agent and
place it immediately after the article title. Preserve the URL exactly,
including its complete query string.

If no image_agent result is present, do not invent an image URL.
"""

journalist_agent = Agent(
    name = "journalist_agent",
    instructions = JOURNALIST_WRITER_PROMPT,
    model = MODEL
)

# %% [markdown]
# ### Update the Orchestrator Agent

# %%
orchestrator_agent.handoffs = [journalist_agent]

# %%
# with trace("journalist test", group_id="Learning AI Engineering Orachestration"):
#     result =  await Runner.run(
#         journalist_agent,
#         input = "Write an article about the following topic: African Jiraffes",
#         max_turns = 20
#     )

# %% [markdown]
# ### Run -- Agent

# %%
with trace("Article Writer with handoff", group_id="Learning AI agents",
           metadata={"topic": "Testing the filters in the traces"}):
    result = await Runner.run(
        orchestrator_agent,
        input = "How one can I transition from Software engineer to AI Engineer?",
        max_turns=10
    )
# Out:
# ✅ search_web: Got results pathways for software engineers to become AI engineers
# ✅ search_web: Got results transition from Software Engineer to AI Engineer
# ✅ fetch_url: Got 9243 chars from https://codebasics.io/blog/software-engineer-to-ai-engineer-
# ✅ fetch_url: Got 19104 chars from https://www.dataquest.io/blog/ai-engineer-roadmap/
# ✅ fetch_url: Got 1618 chars from https://superml.org/roadmap/ai-engineer
# ✅ fetch_url: Got 16648 chars from https://zenvanriel.com/ai-engineer-blog/ai-career-pathways-p
# ✅ fetch_url: Got 17698 chars from https://www.projectpro.io/article/software-engineer-to-ai-en
# ✅ fetch_url: Got 6458 chars from https://www.linkedin.com/pulse/software-engineer-ai-12-month
# ✅ fetch_url: Got 9190 chars from https://medium.com/data-science-collective/the-6-month-roadm
# 🎨 Generating image for: A serene and inviting workspace designed for an AI engineering environment. The setting features a sleek, modern desk with a high-tech laptop open, displaying code on the screen. In the background, there’s a large window revealing a bright, sunny day outside, illuminating the room with natural light. Potted plants add a touch of greenery, while technical books related to machine learning and AI are neatly stacked on one side. The overall mood is one of focus and creativity, reflecting a transition from traditional software development to the innovative field of AI engineering. Soft, warm colors are used to enhance a calm yet inspiring atmosphere.
# ✅ Image uploaded: https://ai-engineering-generated-images-2026.s3.amazonaws.com/generated-images/9710956d-8dc1-4aad-9e3e-ecd47fc425a9.png?AWSAccessKeyId=AKIATGZKK7WFZMZZIARY&Signature=ebsXhqE1R2mgAGsv7ZMsj%2FUxB%2FI%3D&Expires=1788035097

# %%
print(f"Agent: {result.last_agent.name}")
print(f"-----")
# for p in GENERATED_IMAGES:
#     display(Image(filename=p))
display(Markdown(result.final_output))
# Out:
# Agent: journalist_agent
# -----
# ![AI Engineering](https://ai-engineering-generated-images-2026.s3.amazonaws.com/generated-images/ae07f372-2736-4e81-9479-8d62a5c2e740.png?AWSAccessKeyId=AKIATGZKK7WFZMZZIARY&Signature=xai0CXhS8UyKyC4fWJ2Jo1QSeyM%3D&Expires=1788034801)
#
# # From Code to Cognition: The Surprising Leap from Software Engineering to AI
#
# As the world hurtles into a future increasingly dominated by artificial intelligence, the question isn’t whether one should transition into this fertile field, but how. For seasoned software engineers, the leap into AI engineering isn’t as daunting as it might seem—contrary to popular belief. While the sector is rapidly evolving, with wild west vibes, a significant 80-99% of the required skills are already embedded in your current tool belt. The real question is: Are you ready to embrace the challenge?
#
# It’s easy to assume that becoming an AI engineer necessitates a PhD in computer science or a deep dive back into academia. This belief can feel like a barrier, especially for those who’ve spent years honing their programming skills. Yet, the truth emerges: a solid software engineering foundation is remarkably transferable to many AI concepts (Wyss, 2026). Instead of scrapping your past experiences, you should leverage them.
#
# ## Demystifying the Skill Set
#
# Programming remains at the heart of AI development. Proficiency in languages like Python is essential, acting as the bedrock upon which various AI frameworks thrive—think TensorFlow or PyTorch. If you've been navigating APIs, debugging, or fine-tuning performance in software, you're already halfway there.
#
# However, let's not ignore your weak spots. A solid grasp of mathematics—especially linear algebra, probability, and statistics—will give you a significant edge. Resources like “Mathematics for Machine Learning” serve as an excellent bridge, making complex theories digestible without inducing paralysis through analysis (ProjectPro, 2026).
#
# What about machine learning and data engineering? More than just buzzwords, these fields demand real-world understanding of algorithms and data handling. Familiarity with tools like Pandas, NumPy, and Scikit-learn isn't just a bonus; it’s practically requisite.
#
# ## Mapping Your Journey
#
# Transitioning from software to AI engineer typically isn’t about sudden, radical changes. Rather, it’s a thoughtful progression through distinct phases.
#
# Begin with grasping the fundamentals of AI and honing your Python skills. You might think of this as your AI boot camp—a place to understand the basics and start building your knowledge arsenal.
#
# Once you have the foundations, roll up your sleeves for some serious hands-on experience. Start with projects that showcase your ability to integrate AI into practical scenarios. From developing chatbots to creating recommendation systems, the goal should be to solve real-world problems. Don't get lost in the weeds of theoretical knowledge; focus instead on building systems that demonstrate AI's tangible benefits (Codebasics, 2026).
#
# Next comes the oft-overlooked aspect of machine learning operations (MLOps). Understanding how to deploy AI models effectively is just as critical as creating them. Familiarize yourself with CI/CD tools, monitoring systems, and performance benchmarks to succeed in a production environment.
#
# ## Riding the Wave of Demand
#
# Here’s the kicker: AI engineering is one of the fastest-growing fields out there. Industries ranging from healthcare to finance are on the hunt for skilled minds capable of leveraging AI technologies. The financial rewards reflect this demand, with transitioning engineers typically seeing a noticeable uptick in their earning potential (ProjectPro, 2026).
#
# Moreover, the scope of work is thrilling. Whether your passion lies in Natural Language Processing, Computer Vision, or Generative AI, various niches allow you to flex both your creative and technical muscles.
#
# ## Learning and Evolving
#
# You might ask: what's the best way to stay ahead in such a rapidly changing landscape? Continuous learning. Explore specialized boot camps or online courses tailored for transitioning software engineers. For instance, the Codebasics AI Engineering Bootcamp is explicitly designed to capitalize on your software expertise while introducing crucial AI concepts (Codebasics, 2026; ProjectPro, 2026).
#
# The only constant in tech is change, and familiarizing yourself with new trends and tools isn’t just advisable—it’s imperative. Gartner predicts that by 2027, 80% of engineers will need to upskill due to the rise of generative AI (Codebasics, 2026).
#
# ## Conclusion: Embrace the Future
#
# In summary, transitioning from a software engineer to an AI engineer is more a strategic pivot than an insurmountable leap. As you harness your existing skills, dive into hands-on projects, and remain committed to lifelong learning, you’ll position yourself not only as a participant in the AI conversation but as a leader in this transformative field.
#
# So, are you ready to step beyond coding and into cognition? The future is waiting, and it’s rife with opportunities for those willing to adapt and innovate amid the chaos.
